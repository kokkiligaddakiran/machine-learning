# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index= pd.date_range('1/1/2000',periods=1000), columns=list('ABCD'))

# %%
df.cumsum().plot()

# %%
df2 = pd.DataFrame(np.random.rand(10,4), columns=['a','b', 'c','d'])

# %%
df2
# Out:
#           a         b         c         d
# 0  0.303382  0.719465  0.346730  0.743373
# 1  0.533549  0.706439  0.263792  0.194698
# 2  0.020043  0.739653  0.300361  0.648904
# 3  0.924825  0.384841  0.935187  0.025517
# 4  0.080906  0.479229  0.318952  0.587708
# 5  0.681893  0.361815  0.750703  0.781503
# 6  0.257934  0.448702  0.858237  0.837167
# 7  0.231187  0.250114  0.487518  0.773787
# 8  0.216209  0.014484  0.424445  0.582522
# 9  0.340607  0.451005  0.023058  0.364255

# %%
df2.T.plot.bar()

# %%
df4 = pd.DataFrame({'a':[1,2,3,4,4,4,4,4,2,4,5,5]})

# %%
df4.plot.hist(alpha=0.5, bins=3,orientation='horizontal')

# %%
df = pd.DataFrame(np.random.rand(10,5), columns=['a','b','c','d','e'])
df.plot.box()

# %%
df.describe()
# Out:
#                a          b          c          d          e
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.583660   0.380538   0.486103   0.436443   0.333533
# std     0.265859   0.253202   0.297480   0.254174   0.285777
# min     0.015693   0.063595   0.103390   0.005665   0.037369
# 25%     0.468412   0.177605   0.257296   0.289898   0.077866
# 50%     0.596121   0.342992   0.493672   0.418549   0.237610
# 75%     0.807114   0.605045   0.695681   0.501849   0.551958
# max     0.871876   0.729317   0.984018   0.908508   0.760078

# %%
df.min()
# Out:
# a    0.015693
# b    0.063595
# c    0.103390
# d    0.005665
# e    0.037369
# dtype: float64

# %%
df.mean()
# Out:
# a    0.583660
# b    0.380538
# c    0.486103
# d    0.436443
# e    0.333533
# dtype: float64

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.980408  0.028304  0.063406  0.445567
# 1  0.696228  0.056947  0.657580  0.727937
# 2  0.856232  0.746085  0.969136  0.201100
# 3  0.608912  0.410054  0.640707  0.998178
# 4  0.464488  0.999198  0.317952  0.614397
# 5  0.522407  0.405979  0.276793  0.114899
# 6  0.144852  0.431033  0.557682  0.762946
# 7  0.986097  0.254206  0.262230  0.079562
# 8  0.775849  0.872400  0.581289  0.557695
# 9  0.897598  0.673315  0.346084  0.342440

# %%
df.plot.area()

# %%
df.plot.area(stacked=False)

# %%
from sklearn.datasets import california_housing

# %%
housing = california_housing.fetch_california_housing()

# %%
housing.data.shape
# Out:
# (20640, 8)

# %%
cities = pd.read_csv('california_cities.csv', index_col='Unnamed: 0')

# %%
import matplotlib.pyplot as plt

# %%
lat, lon = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']

# %%
plt.scatter(lat, lon, c=np.log10(population), s=area, cmap='viridis')
plt.colorbar(label='log population')

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# %%
df['b'] = df['b'] + np.arange(1000)

# %%
df.plot.hexbin(x='a', y='b', gridsize=10)

# %%
df.plot.scatter(x='a',y='b')

# %%
df = pd.DataFrame(3 * np.random.rand(4, 2), index=['a', 'b', 'c', 'd'], columns=['x', 'y'])

# %%
df
# Out:
#           x         y
# a  2.187693  0.759686
# b  2.083020  2.366084
# c  1.937520  0.002349
# d  2.791722  1.388015

# %%
df.plot.pie( 'y', subplots=False, figsize=(12, 3), autopct='%.3f')

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#             a         b         c         d
# 0    1.320928 -0.497651 -0.704937 -0.607519
# 1    0.071023  0.934619  0.630305 -0.250363
# 2   -0.189940 -0.002781  0.372494  1.367628
# 3   -1.811003  0.510640  0.210051 -0.515344
# 4    1.383195  2.002964 -2.440949  1.224698
# 5    0.133238 -0.009161  1.626487 -1.364334
# 6   -0.568767 -1.769639  0.945449 -1.583848
# 7    2.069609  0.304085  2.055143 -0.819893
# 8   -0.222001  0.884624 -0.114344 -1.514843
# 9   -0.633815  2.510884 -0.338587 -0.041580
# 10   1.115927  0.440137  0.957692  1.020025
# 11   0.625489  0.334736  2.428998 -2.075959
# 12  -1.372982  0.564201 -0.277501 -0.625427
# 13   1.756702 -0.333970  0.667170  1.374362
# 14  -1.473826 -0.214182  0.692365 -1.060040
# 15   0.593189  1.682557 -0.998460  0.024124
# 16   2.348375 -2.100061 -1.143073 -0.904756
# 17   0.081028  0.418176  0.489213 -0.573677
# 18   1.573785  0.475990 -0.300849 -1.216642
# 19  -1.136856  1.333982  0.462796 -0.438874
# ...

# %%
df.plot(subplots=True, figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f21ff1139e8>,
# ...
#       dtype=object)

# %%
from sklearn.datasets import load_digits

# %%
data = load_digits()

# %%
plt.imshow(data.data[0].reshape(8,8), cmap='gray')

# %%
plt.imshow(data.data[1].reshape(8,8), cmap='gray')

# %%
data.data[1].reshape(8,8)
# Out:
# array([[ 0.,  0.,  0., 12., 13.,  5.,  0.,  0.],
#        [ 0.,  0.,  0., 11., 16.,  9.,  0.,  0.],
#        [ 0.,  0.,  3., 15., 16.,  6.,  0.,  0.],
#        [ 0.,  7., 15., 16., 16.,  2.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  3.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  6.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  6.,  0.,  0.],
#        [ 0.,  0.,  0., 11., 16., 10.,  0.,  0.]])

# %%
from sklearn.feature_extraction import image

# %%
from skimage.io import imread

# %%
cat = imread('cat.jpg')

# %%
cat.shape

# %%
plt.imshow(cat)

# %%
fig = plt.figure(figsize=(10,10))
fig.subplots_adjust(hspace=0.1, wspace=0.4)
for i in range(1,7):
    ax = fig.add_subplot(2,3,i)
    ax.text(0.5,0.5, "good")
    plt.xticks(np.arange(5), ('T', 'D', 'H', 'S', 'S'))
